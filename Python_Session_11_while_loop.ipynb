# %% [markdown]
# # While loop

# %%
i=0
while i<5:
    print(i)
    if i==3:
        break
    i+=1
# Out:
# 0
# 1
# 2
# 3

# %%
i=4
while i<5 and i!=0:
    print('hi')
    i-=1
# Out:
# hi
# hi
# hi
# hi

# %%
i=7
while i > 6 and i!=9:
    print('hi')
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# ...
